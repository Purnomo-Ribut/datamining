# %% [markdown]
# # **Tugas 2 - Diskritisasi**
#
#
#
# 1.   Carilah data yang bertipe numerik ( data klassifikasi)
# 2.   Lakukan proses diskritisasi dengan equal width dan equal frequency
# 3.   Lakukan proses diskritisasi dengan basis entropy
# 4.   Kumpulkan tugas dengan link github ( web statis dari jupyter book)

# %% [markdown]
# **Cari Data**
#
# Sourca Data [link](https://www.kaggle.com/datasets/saurabh00007/iriscsv)

# %% [markdown]
# Teori
#
# **Discretization**
#
# Discretization atau diskretisasi adalah proses di mana kita dapat mengubah variabel kontinu, model atau fungsi menjadi bentuk diskrit. kita dapat melakukan ini dengan membuat satu set interval yang berdekatan yang melintasi rentang variabel / model / fungsi yang diinginkan.
#
# **Pendekatan Discretization**
#
# *Unsupervised:*
#
# a. Equal-Width
#
# pada pendekatan ini data dibagi menjadi k interval dengan ukuran lebar yang sama.
#
#
# Lebar interval adalah:
# w = (maks-min) / k
#
# Dan batas intervalnya adalah:
# min + w, min + 2w, …, min + (k-1) w
#
# b. Equal-Frequency
# pada pendekatan ini membagi data menjadi kelompok k yang masing-masing kelompok berisi kira-kira jumlah nilai yang sama.
#
# Untuk kedua metode, cara terbaik untuk menentukan k adalah dengan melihat histogram dan mencoba interval atau grup yang berbeda.

# %%
#awal mengimpor library pandas dan numpy 
import pandas as pd

# %%
#lalu menampilkan data yang sudah di upload di google drive
df = pd.read_csv('/content/drive/MyDrive/datamining/tugas/iris.zip')
#menampikan data dari bawah karena ada survived yang berbeda
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Show dataset shape / # Tampilkan bentuk kumpulan data
number_of_columns = df.shape[1]
# Show all columns for dataset / # Tampilkan semua kolom untuk kumpulan data
pd.set_option('display.max_columns', number_of_columns)
pd.set_option('display.max_rows', number_of_columns)
# Tampilkan semua kolom dari kerangka data
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# CONSTAN SERIES

SEPAL_LENGTH_SERIES = df["SepalLengthCm"]
SEPAL_WIDTH_SERIES = df["SepalWidthCm"]
PETAL_LENGTH_SERIES = df["PetalLengthCm"]
PETAL_WIDTH_SERIES = df["PetalWidthCm"]

# Class Variety Name 
IRIS_VARIETY = df["Species"]

# %% [markdown]
# **Menghitung Data**
#
# pada kali ini perhitungan data menggunakan method cut
#
#
# ```
# # Syntax cut
# pd.cut(series, interval, right=True, label)
# ```
#
#
# * cut merupakan sebuah method pada library pandas untuk melakukan perhitungan *equal frequency intervals*
